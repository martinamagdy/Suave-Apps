# %%
# Import Dependencies
import pandas as pd
from sqlalchemy import create_engine
#import mysql_conn

# %% [markdown]
# ### Import Data

# %%
# Read in Apple store data
apple = pd.read_csv('Raw_Data/Apple/AppleStore.csv')
apple.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# 0          4.0              4.5   6.3.5          4+         Games
# 1          4.0              3.5   8.2.2          4+  Productivity
# 2          3.5              4.5   5.0.0          4+       Weather
# 3          4.0              4.5  5.10.0         12+      Shopping
# 4          4.5              5.0   7.5.1          4+     Reference
#
#    sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0               38                5        10        1
# 1               37                5        23        1
# 2               37                5         3        1
# 3               37                5         9        1
# 4               37                5        45        1

# %%
# Read in Play Store data
google = pd.read_csv('Raw_Data/Google/googleplaystore.csv')
google.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# ### Rename Columns

# %%
# Rename Apple columns
a_cols = ['track_name', 'id', 'size_bytes', 'price', 'user_rating', 'cont_rating', 'prime_genre']
apple = apple[a_cols]
apple = apple.rename(columns = {'track_name':'a_name', 
                                'id':'a_id',
                                'size_bytes':'a_size_bytes', 
                                'price':'a_price', 
                                'user_rating':'a_user_rating', 
                                'cont_rating':'a_content_rating', 
                                'prime_genre':'a_category'})
apple.head()
# Out:
#                                               a_name       a_id  a_size_bytes  \
# 0                                    PAC-MAN Premium  281656475     100788224
# 1                          Evernote - stay organized  281796108     158578688
# 2    WeatherBug - Local Weather, Radar, Maps, Alerts  281940292     100524032
# 3  eBay: Best App to Buy, Sell, Save! Online Shop...  282614216     128512000
# 4                                              Bible  282935706      92774400
#
#    a_price  a_user_rating a_content_rating    a_category
# 0     3.99            4.0               4+         Games
# 1     0.00            4.0               4+  Productivity
# 2     0.00            3.5               4+       Weather
# 3     0.00            4.0              12+      Shopping
# 4     0.00            4.5               4+     Reference

# %%
#google.loc[google.g_name.str.contains('eBay')]

# %%
# Rename Google columns
g_cols = ['App', 'Size', 'Price', 'Rating', 'Content Rating', 'Category']
google = google[g_cols]
google = google.rename(columns = {'App':'g_name', 
                        'Size':'g_size_mb', 
                        'Price':'g_price', 
                        'Rating':'g_user_rating', 
                        'Content Rating':'g_content_rating', 
                        'Category':'g_category'})
google.head()
# Out:
#                                               g_name g_size_mb g_price  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook       19M       0
# 1                                Coloring book moana       14M       0
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...      8.7M       0
# 3                              Sketch - Draw & Paint       25M       0
# 4              Pixel Draw - Number Art Coloring Book      2.8M       0
#
#    g_user_rating g_content_rating      g_category
# 0            4.1         Everyone  ART_AND_DESIGN
# 1            3.9         Everyone  ART_AND_DESIGN
# 2            4.7         Everyone  ART_AND_DESIGN
# 3            4.5             Teen  ART_AND_DESIGN
# 4            4.3         Everyone  ART_AND_DESIGN

# %% [markdown]
# ### Remove Apps that do not appear on both datasets

# %%
# Drop duplicates
google = google.drop_duplicates(subset = 'g_name')
apple = apple.drop_duplicates(subset = 'a_name')

# %%
apple_merge = apple.rename(columns = {'a_name':'name'})
google_merge = google.rename(columns = {'g_name':'name'})

# %%
# Remove apps that do not appear in both datasets
apps_merge = pd.merge(apple_merge, google_merge, on = 'name')

# %%
apps_merge.head()
# Out:
#            name       a_id  a_size_bytes  a_price  a_user_rating  \
# 0         Bible  282935706      92774400      0.0            4.5
# 1      Facebook  284882215     389879808      0.0            3.5
# 2      LinkedIn  288429040     273844224      0.0            3.5
# 3  Google Earth  293622097      37214208      0.0            3.5
# 4       PAC-MAN  293778748     100849664      0.0            3.0
#
#   a_content_rating         a_category           g_size_mb g_price  \
# 0               4+          Reference  Varies with device       0
# 1               4+  Social Networking  Varies with device       0
# 2               4+  Social Networking  Varies with device       0
# 3               4+             Travel  Varies with device       0
# 4               4+              Games                 37M       0
#
#    g_user_rating g_content_rating           g_category
# 0            4.7             Teen  BOOKS_AND_REFERENCE
# 1            4.1             Teen               SOCIAL
# 2            4.2         Everyone               SOCIAL
# 3            4.3         Everyone     TRAVEL_AND_LOCAL
# 4            4.2         Everyone                 GAME

# %%
common_apps = list(apps_merge.name)

# %% [markdown]
# # Column Formatting

# %% [markdown]
# ### Format app size columns

# %%
#print(apple.a_size_mb.unique())
#print(google.g_size_mb.unique())
apps_merge.g_size_mb.unique()
# Out:
# array(['Varies with device', '37M', '46M', '63M', '33M', '34M', '19M',
#        '61M', '35M', '31M', '30M', '20M', '8.3M', '23M', '32M', '36M',
#        '18M', '2.3M', '43M', '41M', '22M', '44M', '42M', '8.7M', '15M',
#        '1.9M', '6.6M', '67M', '90M', '29M', '69M', '80M', '3.9M', '96M',
#        '12M', '48M', '98M', '85M', '16M', '17M', '73M', '21M', '49M',
#        '25M', '62M', '94M', '76M', '7.8M', '50M', '11M', '14M', '66M',
#        '45M', '100M', '24M', '53M', '68M', '59M', '74M', '71M', '9.5M',
#        '5.8M', '75M', '79M', '70M', '58M', '4.2M', '92M', '82M', '95M',
#        '7.4M', '57M', '88M', '51M', '26M', '6.9M', '56M', '28M', '99M',
#        '6.5M', '7.6M', '72M', '40M', '52M', '78M', '39M', '83M', '7.9M',
#        '54M', '27M', '97M', '4.0M', '93M', '64M', '4.9M', '65M', '55M'],
#       dtype=object)

# %%
# Convert Apple app size from bytes to megabytes
a_size_mb = []

for byte in list(apps_merge.a_size_bytes):
    megabyte = byte / 1024 / 1024
    a_size_mb.append(megabyte)

apps_merge.a_size_bytes = a_size_mb
apps_merge = apps_merge.rename(columns = {'a_size_bytes':'a_size_mb'})

# Round decimal places
apps_merge.a_size_mb = apps_merge.a_size_mb.round(1)

# %%
# Remove 'M' from Google app sizes
apps_merge.g_size_mb = apps_merge.g_size_mb.str[:-1]

# %%
# Remove rows where google size 'varies with device'
apps_merge = apps_merge.loc[apps_merge['g_size_mb'] != 'Varies with devic']

# %%
apps_merge.head()
# Out:
#                   name       a_id  a_size_mb  a_price  a_user_rating  \
# 4              PAC-MAN  293778748       96.2      0.0            3.0
# 7         Citi Mobile®  301724680      268.2      0.0            3.5
# 9              DIRECTV  307386350      144.4      0.0            3.5
# 15  Wells Fargo Mobile  311548709       54.7      0.0            3.0
# 16         USAA Mobile  312325565      156.8      0.0            4.0
#
#    a_content_rating     a_category g_size_mb g_price  g_user_rating  \
# 4                4+          Games        37       0            4.2
# 7                4+        Finance        46       0            4.0
# 9                4+  Entertainment        63       0            4.1
# 15               4+        Finance        37       0            4.4
# 16               4+        Finance        33       0            4.5
#
#    g_content_rating g_category
# 4          Everyone       GAME
# 7          Everyone    FINANCE
# 9              Teen     FAMILY
# 15         Everyone    FINANCE
# 16         Everyone    FINANCE

# %% [markdown]
# ### Format price columns

# %%
print(apps_merge.a_price.unique())
print(apps_merge.g_price.unique())
# Out:
# [ 0.    1.99  4.99  0.99 19.99  9.99  2.99 14.99  6.99  3.99  7.99  5.99]
# ['0' '$0.99' '$4.99' '$1.99' '$24.99' '$14.99' '$9.99' '$2.99' '$1.20'
#  '$7.99' '$6.99' '$3.99' '$5.99']

# %%
apps_merge.loc[apps_merge.g_price.str.contains('Everyone')]
# Out:
# Empty DataFrame
# Columns: [name, a_id, a_size_mb, a_price, a_user_rating, a_content_rating, a_category, g_size_mb, g_price, g_user_rating, g_content_rating, g_category]
# Index: []

# %%
# Drop rows with errors
apps_merge = apps_merge[~apps_merge.g_price.str.contains("Everyone")]

# Format data to match Apple dataset
apps_merge['g_price'] = apps_merge.g_price.str.lstrip('$')


(apps_merge.g_price.unique())
# Out:
# array(['0', '0.99', '4.99', '1.99', '24.99', '14.99', '9.99', '2.99',
#        '1.20', '7.99', '6.99', '3.99', '5.99'], dtype=object)

# %%
apps_merge.head()
# Out:
#                   name       a_id  a_size_mb  a_price  a_user_rating  \
# 4              PAC-MAN  293778748       96.2      0.0            3.0
# 7         Citi Mobile®  301724680      268.2      0.0            3.5
# 9              DIRECTV  307386350      144.4      0.0            3.5
# 15  Wells Fargo Mobile  311548709       54.7      0.0            3.0
# 16         USAA Mobile  312325565      156.8      0.0            4.0
#
#    a_content_rating     a_category g_size_mb g_price  g_user_rating  \
# 4                4+          Games        37       0            4.2
# 7                4+        Finance        46       0            4.0
# 9                4+  Entertainment        63       0            4.1
# 15               4+        Finance        37       0            4.4
# 16               4+        Finance        33       0            4.5
#
#    g_content_rating g_category
# 4          Everyone       GAME
# 7          Everyone    FINANCE
# 9              Teen     FAMILY
# 15         Everyone    FINANCE
# 16         Everyone    FINANCE

# %%
apps_merge.head()
# Out:
#                   name       a_id  a_size_mb  a_price  a_user_rating  \
# 4              PAC-MAN  293778748       96.2      0.0            3.0
# 7         Citi Mobile®  301724680      268.2      0.0            3.5
# 9              DIRECTV  307386350      144.4      0.0            3.5
# 15  Wells Fargo Mobile  311548709       54.7      0.0            3.0
# 16         USAA Mobile  312325565      156.8      0.0            4.0
#
#    a_content_rating     a_category g_size_mb g_price  g_user_rating  \
# 4                4+          Games        37       0            4.2
# 7                4+        Finance        46       0            4.0
# 9                4+  Entertainment        63       0            4.1
# 15               4+        Finance        37       0            4.4
# 16               4+        Finance        33       0            4.5
#
#    g_content_rating g_category
# 4          Everyone       GAME
# 7          Everyone    FINANCE
# 9              Teen     FAMILY
# 15         Everyone    FINANCE
# 16         Everyone    FINANCE

# %% [markdown]
# ### Format content rating

# %%
apps_merge.g_content_rating.unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+'], dtype=object)

# %%
apps_merge.a_content_rating.unique()
# Out:
# array(['4+', '12+', '17+', '9+'], dtype=object)

# %%
# Create new DataFrame to identify equivalent content ratings
content_ratings = pd.DataFrame(data = {'id':[1, 2, 3, 4],  
                     'apple':['4+', '9+', '12+', '17+'], 
                     'google':['Everyone', 'Everyone 10+', 'Teen', 'Mature 17+']})
content_ratings = content_ratings.set_index('id')
content_ratings
# Out:
#    apple        google
# id
# 1     4+      Everyone
# 2     9+  Everyone 10+
# 3    12+          Teen
# 4    17+    Mature 17+

# %%
# Rename content ratings to match

# Apple
apps_merge['a_content_rating'] = apps_merge.a_content_rating.replace('4+', '1')
apps_merge['a_content_rating'] = apps_merge.a_content_rating.replace('9+', '2')
apps_merge['a_content_rating'] = apps_merge.a_content_rating.replace('12+', '3')
apps_merge['a_content_rating'] = apps_merge.a_content_rating.replace('17+', '4')

# Google
apps_merge['g_content_rating'] = apps_merge.g_content_rating.replace('Everyone', '1')
apps_merge['g_content_rating'] = apps_merge.g_content_rating.replace('Everyone 10+', '2')
apps_merge['g_content_rating'] = apps_merge.g_content_rating.replace('Teen', '3')
apps_merge['g_content_rating'] = apps_merge.g_content_rating.replace('Mature 17+', '4')

# %%
apps_merge.head()
# Out:
#                   name       a_id  a_size_mb  a_price  a_user_rating  \
# 4              PAC-MAN  293778748       96.2      0.0            3.0
# 7         Citi Mobile®  301724680      268.2      0.0            3.5
# 9              DIRECTV  307386350      144.4      0.0            3.5
# 15  Wells Fargo Mobile  311548709       54.7      0.0            3.0
# 16         USAA Mobile  312325565      156.8      0.0            4.0
#
#    a_content_rating     a_category g_size_mb g_price  g_user_rating  \
# 4                 1          Games        37       0            4.2
# 7                 1        Finance        46       0            4.0
# 9                 1  Entertainment        63       0            4.1
# 15                1        Finance        37       0            4.4
# 16                1        Finance        33       0            4.5
#
#    g_content_rating g_category
# 4                 1       GAME
# 7                 1    FINANCE
# 9                 3     FAMILY
# 15                1    FINANCE
# 16                1    FINANCE

# %% [markdown]
# ### Categories

# %%
apps_merge.a_category.unique()
# Out:
# array(['Games', 'Finance', 'Entertainment', 'Shopping', 'News',
#        'Productivity', 'Food & Drink', 'Sports', 'Business', 'Travel',
#        'Education', 'Social Networking', 'Medical', 'Weather',
#        'Photo & Video', 'Lifestyle', 'Book', 'Catalogs', 'Utilities',
#        'Health & Fitness'], dtype=object)

# %%
apps_merge.g_category.unique()
# Out:
# array(['GAME', 'FINANCE', 'FAMILY', 'SHOPPING', 'NEWS_AND_MAGAZINES',
#        'PRODUCTIVITY', 'FOOD_AND_DRINK', 'SPORTS', 'BUSINESS',
#        'ENTERTAINMENT', 'MAPS_AND_NAVIGATION', 'TRAVEL_AND_LOCAL',
#        'EDUCATION', 'SOCIAL', 'MEDICAL', 'LIFESTYLE', 'WEATHER',
#        'PHOTOGRAPHY', 'VIDEO_PLAYERS', 'COMMUNICATION',
#        'HEALTH_AND_FITNESS', 'ART_AND_DESIGN'], dtype=object)

# %%
apps_merge.a_category.unique()
# Out:
# array(['Games', 'Finance', 'Entertainment', 'Shopping', 'News',
#        'Productivity', 'Food & Drink', 'Sports', 'Business', 'Travel',
#        'Education', 'Social Networking', 'Medical', 'Weather',
#        'Photo & Video', 'Lifestyle', 'Book', 'Catalogs', 'Utilities',
#        'Health & Fitness'], dtype=object)

# %%
#categories = pd.DataFrame(data = {'id':list(range(1, 23)),  
#                     'apple':['Reference', 'Social Networking', 'Travel', 'Games',
#                              'Food & Drink', 'Utilities', 'Finance', 'Entertainment',
#                              'Business', 'Shopping', 'News', 'Photo & Video', 'Productivity',
#                              'Navigation', 'Sports', 'Education', 'Health & Fitness',
#                              'Lifestyle', 'Medical', 'Weather', 'Book', 'Catalogs'], 
#                     'google':['BOOKS_AND_REFERENCE', 'SOCIAL', 'TRAVEL_AND_LOCAL', 'GAME',
#                               'FOOD_AND_DRINK', 'TOOLS', 'FINANCE', 'FAMILY', 'ENTERTAINMENT',
#                               'PRODUCTIVITY', 'BUSINESS', 'COMMUNICATION', 'SHOPPING',
#                               'NEWS_AND_MAGAZINES', 'HEALTH_AND_FITNESS', 'SPORTS',
#                               'MAPS_AND_NAVIGATION', 'EDUCATION', 'LIFESTYLE', 'PHOTOGRAPHY',
#                               'MEDICAL', 'WEATHER', 'VIDEO_PLAYERS', 'ART_AND_DESIGN']})
#categories = content_ratings.set_index('id')
#categories

# %%
apps_merge.a_category.unique()
# Out:
# array(['Games', 'Finance', 'Entertainment', 'Shopping', 'News',
#        'Productivity', 'Food & Drink', 'Sports', 'Business', 'Travel',
#        'Education', 'Social Networking', 'Medical', 'Weather',
#        'Photo & Video', 'Lifestyle', 'Book', 'Catalogs', 'Utilities',
#        'Health & Fitness'], dtype=object)

# %%
apps_merge.loc[apps_merge['a_category'] == 'Travel']
# Out:
#                   name       a_id  a_size_mb  a_price  a_user_rating  \
# 29        DB Navigator  343555245       80.9      0.0            3.5
# 30  Southwest Airlines  344542975       84.7      0.0            3.0
# 46           Fly Delta  388491656      134.3      0.0            3.0
# 78     United Airlines  449945214      134.4      0.0            2.5
#
#    a_content_rating a_category g_size_mb g_price  g_user_rating  \
# 29                1     Travel        20       0            4.0
# 30                1     Travel       8.3       0            3.9
# 46                1     Travel        46       0            3.7
# 78                1     Travel        80       0            3.5
#
#    g_content_rating           g_category
# 29                1  MAPS_AND_NAVIGATION
# 30                1     TRAVEL_AND_LOCAL
# 46                1     TRAVEL_AND_LOCAL
# 78                1     TRAVEL_AND_LOCAL

# %%
apps_merge.loc[apps_merge['g_category'] == 'TRAVEL_AND_LOCAL']
# Out:
#                   name       a_id  a_size_mb  a_price  a_user_rating  \
# 30  Southwest Airlines  344542975       84.7      0.0            3.0
# 46           Fly Delta  388491656      134.3      0.0            3.0
# 78     United Airlines  449945214      134.4      0.0            2.5
#
#    a_content_rating a_category g_size_mb g_price  g_user_rating  \
# 30                1     Travel       8.3       0            3.9
# 46                1     Travel        46       0            3.7
# 78                1     Travel        80       0            3.5
#
#    g_content_rating        g_category
# 30                1  TRAVEL_AND_LOCAL
# 46                1  TRAVEL_AND_LOCAL
# 78                1  TRAVEL_AND_LOCAL

# %%
#apps_merge.loc[~(apps_merge['a_category'] == apps_merge['g_category'])]

# %%
# Reset numeric values of index
apps_merge = apps_merge.reset_index(drop = True)
apps_merge
# Out:
#                                name        a_id  a_size_mb  a_price  \
# 0                           PAC-MAN   293778748       96.2     0.00
# 1                      Citi Mobile®   301724680      268.2     0.00
# 2                           DIRECTV   307386350      144.4     0.00
# 3                Wells Fargo Mobile   311548709       54.7     0.00
# 4                       USAA Mobile   312325565      156.8     0.00
# 5                          Best Buy   314855255      172.1     0.00
# 6                          Sky News   316391924       87.4     0.00
# 7                          Mad Libs   326885152      113.0     0.00
# 8                           Dropbox   327630330      172.4     0.00
# 9                         Starbucks   331177714      128.8     0.00
# 10                              NBA   335744614      106.9     0.00
# 11                   AirWatch Agent   338761996       23.6     0.00
# 12                           Redbox   339532909       80.0     0.00
# 13                     DB Navigator   343555245       80.9     0.00
# 14               Southwest Airlines   344542975       84.7     0.00
# 15                        Solitaire   359917414       97.2     0.00
# 16                      Amex Mobile   362348516      101.1     0.00
# 17              Fruit Ninja Classic   362949845       99.7     1.99
# 18                     Chase Mobile   370697773       33.3     0.00
# 19                              TED   376183339       80.2     0.00
# 20                           Edmodo   378352300      122.0     0.00
# 21                        Fly Delta   388491656      134.3     0.00
# 22           Paprika Recipe Manager   392408028        9.9     4.99
# 23            NBA JAM by EA SPORTS™   402370879      391.2     4.99
# 24                     Fruit Ninja®   403858572      156.2     0.00
# 25                     The Guardian   409128287       88.7     0.00
# 26             Mad Skills Motocross   410229362       16.2     0.99
# 27                       Temple Run   420009108       62.9     0.00
# 28                  Angry Birds Rio   420635506      131.9     0.00
# 29                         My Horse   421167112      287.9     0.00
# ..                              ...         ...        ...      ...
# 208       Choices: Stories You Play  1071310449      103.6     0.00
# 209   My Little Pony: Harmony Quest  1072380719      681.3     0.00
# 210              Smashy Road: Arena  1073476012      198.7     0.00
# 211      FINAL FANTASY BRAVE EXVIUS  1078553808      103.9     0.00
# 212  King of Avalon: Dragon Warfare  1084930849      182.7     0.00
# 213           Retro City Rampage DX  1088540036       14.9     4.99
# 214     PewDiePie's Tuber Simulator  1093190533      254.4     0.00
# 215                      Pokémon GO  1094591345      277.3     0.00
# 216                     PAC-MAN Pop  1102508135      235.7     0.00
# 217               T-Mobile Tuesdays  1111876388       74.5     0.00
# 218             Geometry Dash World  1112307917       61.3     0.00
# 219   RollerCoaster Tycoon® Classic  1113736426      405.1     5.99
# 220                         diep.io  1114751883       31.5     0.00
# 221                  Dr. Panda Farm  1116025351       94.4     2.99
# 222                The Game of Life  1117405948      291.3     2.99
# 223                  Endless Ducker  1117844680      152.4     0.00
# 224    Out There Chronicles - Ep. 1  1119644926      103.6     1.99
# 225               Angry Birds Blast  1122444037      123.6     0.00
# 226                      The EO Bar  1128311260       39.5     6.99
# 227   Premier League - Official App  1138895159       71.0     0.00
# 228                     Whataburger  1141643627      127.2     0.00
# 229             Narcos: Cartel Wars  1143052259      170.6     0.00
# 230                 Super Mario Run  1145275343      185.2     0.00
# 231    Vikings: an Archer's Journey  1145485982      124.7     2.99
# 232                Infinite Painter  1146543227       21.4     0.00
# 233       Don't Starve: Shipwrecked  1147297267      604.3     4.99
# 234                   Pineapple Pen  1159035153       93.4     0.00
# 235               Super Jabber Jump  1164013670      140.1     0.00
# 236                         Ao Oni2  1178880179       82.7     0.00
# 237           Peppa Pig: Party Time  1179475725      240.3     0.99
#
#      a_user_rating a_content_rating        a_category g_size_mb g_price  \
# 0              3.0                1             Games        37       0
# 1              3.5                1           Finance        46       0
# 2              3.5                1     Entertainment        63       0
# 3              3.0                1           Finance        37       0
# 4              4.0                1           Finance        33       0
# 5              4.0                1          Shopping        34       0
# 6              3.0                3              News        19       0
# 7              3.0                1     Entertainment        61       0
# 8              3.5                1      Productivity        61       0
# 9              4.5                1      Food & Drink        35       0
# 10             3.5                1            Sports        35       0
# 11             2.5                1          Business        31       0
# 12             3.0                3     Entertainment        30       0
# 13             3.5                1            Travel        20       0
# 14             3.0                1            Travel       8.3       0
# 15             4.5                1             Games        23       0
# 16             4.0                1           Finance        32       0
# 17             4.5                1             Games        36    0.99
# 18             4.5                1           Finance        32       0
# 19             3.5                3         Education        18       0
# 20             3.5                1         Education        18       0
# 21             3.0                1            Travel        46       0
# 22             4.5                4      Food & Drink       2.3    4.99
# 23             4.0                1             Games        43    4.99
# 24             4.5                1             Games        41       0
# 25             5.0                3              News        22       0
# 26             4.5                3             Games        44       0
# 27             4.5                2             Games        42       0
# 28             4.5                1             Games        46       0
# 29             4.5                1             Games       8.7       0
# ..             ...              ...               ...       ...     ...
# 208            4.5                3             Games        93       0
# 209            4.0                1     Entertainment        26       0
# 210            4.5                2             Games        53       0
# 211            4.5                3             Games        83       0
# 212            4.0                2             Games        64       0
# 213            4.5                3             Games        16    2.99
# 214            5.0                2             Games        96       0
# 215            3.0                2             Games        85       0
# 216            4.5                1             Games        54       0
# 217            2.5                4         Lifestyle        21       0
# 218            4.5                1             Games        63       0
# 219            4.0                1             Games        69    5.99
# 220            4.0                2             Games        20       0
# 221            4.0                1         Education        46    2.99
# 222            4.5                1             Games        63    2.99
# 223            4.0                1             Games        41       0
# 224            4.0                3             Games        44    2.99
# 225            4.5                1             Games        99       0
# 226            5.0                1  Health & Fitness        34    6.99
# 227            3.5                3            Sports        24       0
# 228            3.0                1      Food & Drink        56       0
# 229            4.5                3             Games        52       0
# 230            2.5                1             Games        70       0
# 231            4.5                2             Games        39       0
# 232            4.0                1      Productivity        29       0
# 233            3.5                2             Games       4.9    4.99
# 234            4.5                1             Games        65       0
# 235            4.5                1             Games        23       0
# 236            4.0                3             Games        48       0
# 237            2.0                1         Education        55    2.99
#
#      g_user_rating g_content_rating           g_category
# 0              4.2                1                 GAME
# 1              4.0                1              FINANCE
# 2              4.1                3               FAMILY
# 3              4.4                1              FINANCE
# 4              4.5                1              FINANCE
# 5              4.4                1             SHOPPING
# 6              4.0                2   NEWS_AND_MAGAZINES
# 7              4.0                1               FAMILY
# 8              4.4                1         PRODUCTIVITY
# 9              4.5                1       FOOD_AND_DRINK
# 10             4.4                1               SPORTS
# 11             3.1                1             BUSINESS
# 12             4.1                1        ENTERTAINMENT
# 13             4.0                1  MAPS_AND_NAVIGATION
# 14             3.9                1     TRAVEL_AND_LOCAL
# 15             4.7                1                 GAME
# 16             4.3                1              FINANCE
# 17             4.3                1                 GAME
# 18             4.6                1              FINANCE
# 19             4.6                2            EDUCATION
# 20             4.1                1            EDUCATION
# 21             3.7                1     TRAVEL_AND_LOCAL
# 22             4.1                1       FOOD_AND_DRINK
# 23             4.3                1               FAMILY
# 24             4.3                1                 GAME
# 25             4.7                3   NEWS_AND_MAGAZINES
# 26             4.0                1                 GAME
# 27             4.3                1                 GAME
# 28             4.4                1                 GAME
# 29             4.5                1               FAMILY
# ..             ...              ...                  ...
# 208            4.6                3                 GAME
# 209            4.1                1               FAMILY
# 210            4.3                2                 GAME
# 211            4.6                3                 GAME
# 212            4.2                2               FAMILY
# 213            4.7                3                 GAME
# 214            4.8                3               FAMILY
# 215            4.1                1                 GAME
# 216            4.3                1               FAMILY
# 217            4.0                1            LIFESTYLE
# 218            4.6                1                 GAME
# 219            4.6                1                 GAME
# 220            4.1                1                 GAME
# 221            4.1                1               FAMILY
# 222            4.4                1                 GAME
# 223            4.5                1                 GAME
# 224            4.4                1               FAMILY
# 225            4.6                1               FAMILY
# 226            4.7                1   HEALTH_AND_FITNESS
# 227            4.3                1               SPORTS
# 228            4.5                1       FOOD_AND_DRINK
# 229            4.7                3               FAMILY
# 230            3.7                1                 GAME
# 231            4.5                1                 GAME
# 232            4.1                1       ART_AND_DESIGN
# 233            4.1                3                 GAME
# 234            4.3                1                 GAME
# 235            4.3                1                 GAME
# 236            4.1                3                 GAME
# 237            3.8                1               FAMILY
#
# [238 rows x 12 columns]

# %% [markdown]
# # Create connection to database

# %%
connection_string = (
    f"root:eAVuM6bo4LgR@localhost/apps_db")
engine = create_engine(f'mysql://{connection_string}?charset=utf8')
#engine = create_engine('sqlite://', echo=False)

# %%
engine.table_names()
# Out:
# ['app_store_descriptions', 'apple_store_descriptions', 'apps']

# %%
apps_merge.to_sql(
    name='apps', con=engine, 
    if_exists='replace', index=True)

# %%
name_desc = pd.read_sql('SELECT apps.name, app_store_descriptions.app_desc FROM app_store_descriptions INNER JOIN apps ON apps.a_id = app_store_descriptions.id', con = engine)

# %%
type(name_desc)
# Out:
# pandas.core.frame.DataFrame

# %%
name_desc.to_csv('name_desc.csv')
