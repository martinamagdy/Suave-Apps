# %%
# Import Dependencies
import pandas as pd
from sqlalchemy import create_engine
import mysql_conn

# %% [markdown]
# ### Import Data

# %%
# Read in Apple store data
apple = pd.read_csv('Raw_Data/Apple/AppleStore.csv')
apple.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# 0          4.0              4.5   6.3.5          4+         Games
# 1          4.0              3.5   8.2.2          4+  Productivity
# 2          3.5              4.5   5.0.0          4+       Weather
# 3          4.0              4.5  5.10.0         12+      Shopping
# 4          4.5              5.0   7.5.1          4+     Reference
#
#    sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0               38                5        10        1
# 1               37                5        23        1
# 2               37                5         3        1
# 3               37                5         9        1
# 4               37                5        45        1

# %%
# Read in Play Store data
google = pd.read_csv('Raw_Data/Google/googleplaystore.csv')
google.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# ### Rename Columns

# %%
# Rename Apple columns
a_cols = ['track_name', 'size_bytes', 'price', 'user_rating', 'cont_rating', 'prime_genre']
apple = apple[a_cols]
apple = apple.rename(columns = {'track_name':'a_name', 
                                'size_bytes':'a_size_bytes', 
                                'price':'a_price', 
                                'user_rating':'a_user_rating', 
                                'cont_rating':'a_content_rating', 
                                'prime_genre':'a_category'})
apple.head()
# Out:
#                                               a_name  a_size_bytes  a_price  \
# 0                                    PAC-MAN Premium     100788224     3.99
# 1                          Evernote - stay organized     158578688     0.00
# 2    WeatherBug - Local Weather, Radar, Maps, Alerts     100524032     0.00
# 3  eBay: Best App to Buy, Sell, Save! Online Shop...     128512000     0.00
# 4                                              Bible      92774400     0.00
#
#    a_user_rating a_content_rating    a_category
# 0            4.0               4+         Games
# 1            4.0               4+  Productivity
# 2            3.5               4+       Weather
# 3            4.0              12+      Shopping
# 4            4.5               4+     Reference

# %%
#google.loc[google.g_name.str.contains('eBay')]

# %%
# Rename Google columns
g_cols = ['App', 'Size', 'Price', 'Rating', 'Content Rating', 'Category']
google = google[g_cols]
google = google.rename(columns = {'App':'g_name', 
                        'Size':'g_size_mb', 
                        'Price':'g_price', 
                        'Rating':'g_user_rating', 
                        'Content Rating':'g_content_rating', 
                        'Category':'g_category'})
google.head()
# Out:
#                                               g_name g_size_mb g_price  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook       19M       0
# 1                                Coloring book moana       14M       0
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...      8.7M       0
# 3                              Sketch - Draw & Paint       25M       0
# 4              Pixel Draw - Number Art Coloring Book      2.8M       0
#
#    g_user_rating g_content_rating      g_category
# 0            4.1         Everyone  ART_AND_DESIGN
# 1            3.9         Everyone  ART_AND_DESIGN
# 2            4.7         Everyone  ART_AND_DESIGN
# 3            4.5             Teen  ART_AND_DESIGN
# 4            4.3         Everyone  ART_AND_DESIGN

# %% [markdown]
# ### Remove Apps that do not appear on both datasets

# %%
# Drop duplicates
google = google.drop_duplicates(subset = 'g_name')
apple = apple.drop_duplicates(subset = 'a_name')

# %%
apple_merge = apple.rename(columns = {'a_name':'name'})
google_merge = google.rename(columns = {'g_name':'name'})

# %%
# Remove apps that do not appear in both datasets
apps_merge = pd.merge(apple_merge, google_merge, on = 'name')

# %%
apps_merge.head()
# Out:
#            name  a_size_bytes  a_price  a_user_rating a_content_rating  \
# 0         Bible      92774400      0.0            4.5               4+
# 1      Facebook     389879808      0.0            3.5               4+
# 2      LinkedIn     273844224      0.0            3.5               4+
# 3  Google Earth      37214208      0.0            3.5               4+
# 4       PAC-MAN     100849664      0.0            3.0               4+
#
#           a_category           g_size_mb g_price  g_user_rating  \
# 0          Reference  Varies with device       0            4.7
# 1  Social Networking  Varies with device       0            4.1
# 2  Social Networking  Varies with device       0            4.2
# 3             Travel  Varies with device       0            4.3
# 4              Games                 37M       0            4.2
#
#   g_content_rating           g_category
# 0             Teen  BOOKS_AND_REFERENCE
# 1             Teen               SOCIAL
# 2         Everyone               SOCIAL
# 3         Everyone     TRAVEL_AND_LOCAL
# 4         Everyone                 GAME

# %%
common_apps = list(apps_merge.name)

# %% [markdown]
# # Column Formatting

# %% [markdown]
# ### Format app size columns

# %%
#print(apple.a_size_mb.unique())
#print(google.g_size_mb.unique())

# %%
# Convert Apple app size from bytes to megabytes
a_size_mb = []

for byte in list(apps_merge.a_size_bytes):
    megabyte = byte / 1024 / 1024
    a_size_mb.append(megabyte)

apps_merge.a_size_bytes = a_size_mb
apps_merge = apps_merge.rename(columns = {'a_size_bytes':'a_size_mb'})

# Round decimal places
apps_merge.a_size_mb = apps_merge.a_size_mb.round(1)

# %%
# Remove 'M' from Google app sizes
apps_merge.g_size_mb = apps_merge.g_size_mb.str[:-1]

# %%
apps_merge.head()
# Out:
#            name  a_size_mb  a_price  a_user_rating a_content_rating  \
# 0         Bible       88.5      0.0            4.5               4+
# 1      Facebook      371.8      0.0            3.5               4+
# 2      LinkedIn      261.2      0.0            3.5               4+
# 3  Google Earth       35.5      0.0            3.5               4+
# 4       PAC-MAN       96.2      0.0            3.0               4+
#
#           a_category          g_size_mb g_price  g_user_rating  \
# 0          Reference  Varies with devic       0            4.7
# 1  Social Networking  Varies with devic       0            4.1
# 2  Social Networking  Varies with devic       0            4.2
# 3             Travel  Varies with devic       0            4.3
# 4              Games                 37       0            4.2
#
#   g_content_rating           g_category
# 0             Teen  BOOKS_AND_REFERENCE
# 1             Teen               SOCIAL
# 2         Everyone               SOCIAL
# 3         Everyone     TRAVEL_AND_LOCAL
# 4         Everyone                 GAME

# %% [markdown]
# ### Format price columns

# %%
print(apps_merge.a_price.unique())
print(apps_merge.g_price.unique())
# Out:
# [ 0.    0.99  2.99  4.99  1.99  3.99 19.99  9.99 14.99  6.99  7.99  5.99]
# ['0' '$2.99' '$4.99' '$0.99' '$3.99' '$1.99' '$24.99' '$14.99' '$9.99'
#  '$1.20' '$7.99' '$6.99' '$5.99']

# %%
apps_merge.loc[apps_merge.g_price.str.contains('Everyone')]
# Out:
# Empty DataFrame
# Columns: [name, a_size_mb, a_price, a_user_rating, a_content_rating, a_category, g_size_mb, g_price, g_user_rating, g_content_rating, g_category]
# Index: []

# %%
# Drop rows with errors
apps_merge = apps_merge[~apps_merge.g_price.str.contains("Everyone")]

# Format data to match Apple dataset
apps_merge['g_price'] = apps_merge.g_price.str.lstrip('$')


(apps_merge.g_price.unique())
# Out:
# array(['0', '2.99', '4.99', '0.99', '3.99', '1.99', '24.99', '14.99',
#        '9.99', '1.20', '7.99', '6.99', '5.99'], dtype=object)

# %%
apps_merge.head()
# Out:
#            name  a_size_mb  a_price  a_user_rating a_content_rating  \
# 0         Bible       88.5      0.0            4.5               4+
# 1      Facebook      371.8      0.0            3.5               4+
# 2      LinkedIn      261.2      0.0            3.5               4+
# 3  Google Earth       35.5      0.0            3.5               4+
# 4       PAC-MAN       96.2      0.0            3.0               4+
#
#           a_category          g_size_mb g_price  g_user_rating  \
# 0          Reference  Varies with devic       0            4.7
# 1  Social Networking  Varies with devic       0            4.1
# 2  Social Networking  Varies with devic       0            4.2
# 3             Travel  Varies with devic       0            4.3
# 4              Games                 37       0            4.2
#
#   g_content_rating           g_category
# 0             Teen  BOOKS_AND_REFERENCE
# 1             Teen               SOCIAL
# 2         Everyone               SOCIAL
# 3         Everyone     TRAVEL_AND_LOCAL
# 4         Everyone                 GAME

# %%
apps_merge.head()
# Out:
#            name  a_size_mb  a_price  a_user_rating a_content_rating  \
# 0         Bible       88.5      0.0            4.5               4+
# 1      Facebook      371.8      0.0            3.5               4+
# 2      LinkedIn      261.2      0.0            3.5               4+
# 3  Google Earth       35.5      0.0            3.5               4+
# 4       PAC-MAN       96.2      0.0            3.0               4+
#
#           a_category          g_size_mb g_price  g_user_rating  \
# 0          Reference  Varies with devic       0            4.7
# 1  Social Networking  Varies with devic       0            4.1
# 2  Social Networking  Varies with devic       0            4.2
# 3             Travel  Varies with devic       0            4.3
# 4              Games                 37       0            4.2
#
#   g_content_rating           g_category
# 0             Teen  BOOKS_AND_REFERENCE
# 1             Teen               SOCIAL
# 2         Everyone               SOCIAL
# 3         Everyone     TRAVEL_AND_LOCAL
# 4         Everyone                 GAME

# %% [markdown]
# ### Format content rating

# %%
apps_merge.g_content_rating.unique()
# Out:
# array(['Teen', 'Everyone', 'Mature 17+', 'Everyone 10+'], dtype=object)

# %%
apps_merge.a_content_rating.unique()
# Out:
# array(['4+', '12+', '17+', '9+'], dtype=object)

# %%
# Create new DataFrame to identify equivalent content ratings
content_ratings = pd.DataFrame(data = {'id':[1, 2, 3, 4],  
                     'apple':['4+', '9+', '12+', '17+'], 
                     'google':['Everyone', 'Everyone 10+', 'Teen', 'Mature 17+']})
content_ratings = content_ratings.set_index('id')
content_ratings
# Out:
#    apple        google
# id
# 1     4+      Everyone
# 2     9+  Everyone 10+
# 3    12+          Teen
# 4    17+    Mature 17+

# %%
# Rename content ratings to match

# Apple
apps_merge['a_content_rating'] = apps_merge.a_content_rating.replace('4+', '1')
apps_merge['a_content_rating'] = apps_merge.a_content_rating.replace('9+', '2')
apps_merge['a_content_rating'] = apps_merge.a_content_rating.replace('12+', '3')
apps_merge['a_content_rating'] = apps_merge.a_content_rating.replace('17+', '4')

# Google
apps_merge['g_content_rating'] = apps_merge.g_content_rating.replace('Everyone', '1')
apps_merge['g_content_rating'] = apps_merge.g_content_rating.replace('Everyone 10+', '2')
apps_merge['g_content_rating'] = apps_merge.g_content_rating.replace('Teen', '3')
apps_merge['g_content_rating'] = apps_merge.g_content_rating.replace('Mature 17+', '4')

# %%
apps_merge.head()
# Out:
#            name  a_size_mb  a_price  a_user_rating a_content_rating  \
# 0         Bible       88.5      0.0            4.5                1
# 1      Facebook      371.8      0.0            3.5                1
# 2      LinkedIn      261.2      0.0            3.5                1
# 3  Google Earth       35.5      0.0            3.5                1
# 4       PAC-MAN       96.2      0.0            3.0                1
#
#           a_category          g_size_mb g_price  g_user_rating  \
# 0          Reference  Varies with devic       0            4.7
# 1  Social Networking  Varies with devic       0            4.1
# 2  Social Networking  Varies with devic       0            4.2
# 3             Travel  Varies with devic       0            4.3
# 4              Games                 37       0            4.2
#
#   g_content_rating           g_category
# 0                3  BOOKS_AND_REFERENCE
# 1                3               SOCIAL
# 2                1               SOCIAL
# 3                1     TRAVEL_AND_LOCAL
# 4                1                 GAME

# %% [markdown]
# ### Categories

# %%
apps_merge.a_category.unique()
# Out:
# array(['Reference', 'Social Networking', 'Travel', 'Games',
#        'Food & Drink', 'Utilities', 'Finance', 'Entertainment',
#        'Business', 'Shopping', 'News', 'Photo & Video', 'Productivity',
#        'Navigation', 'Sports', 'Education', 'Health & Fitness',
#        'Lifestyle', 'Medical', 'Weather', 'Book', 'Catalogs'],
#       dtype=object)

# %%
apps_merge.g_category.unique()

# %%
apps_merge.a_category.unique()
# Out:
# array(['Reference', 'Social Networking', 'Travel', 'Games',
#        'Food & Drink', 'Utilities', 'Finance', 'Entertainment',
#        'Business', 'Shopping', 'News', 'Photo & Video', 'Productivity',
#        'Navigation', 'Sports', 'Education', 'Health & Fitness',
#        'Lifestyle', 'Medical', 'Weather', 'Book', 'Catalogs'],
#       dtype=object)

# %%
categories = pd.DataFrame(data = {'id':list(range(1, 23)),  
                     'apple':['Reference', 'Social Networking', 'Travel', 'Games',
                              'Food & Drink', 'Utilities', 'Finance', 'Entertainment',
                              'Business', 'Shopping', 'News', 'Photo & Video', 'Productivity',
                              'Navigation', 'Sports', 'Education', 'Health & Fitness',
                              'Lifestyle', 'Medical', 'Weather', 'Book', 'Catalogs'], 
                     'google':['BOOKS_AND_REFERENCE', 'SOCIAL', 'TRAVEL_AND_LOCAL', 'GAME',
                               'FOOD_AND_DRINK', 'TOOLS', 'FINANCE', 'FAMILY', 'ENTERTAINMENT',
                               'PRODUCTIVITY', 'BUSINESS', 'COMMUNICATION', 'SHOPPING',
                               'NEWS_AND_MAGAZINES', 'HEALTH_AND_FITNESS', 'SPORTS',
                               'MAPS_AND_NAVIGATION', 'EDUCATION', 'LIFESTYLE', 'PHOTOGRAPHY',
                               'MEDICAL', 'WEATHER', 'VIDEO_PLAYERS', 'ART_AND_DESIGN']})
categories = content_ratings.set_index('id')
categories

# %%
apps_merge.a_category.unique()
# Out:
# array(['Reference', 'Social Networking', 'Travel', 'Games',
#        'Food & Drink', 'Utilities', 'Finance', 'Entertainment',
#        'Business', 'Shopping', 'News', 'Photo & Video', 'Productivity',
#        'Navigation', 'Sports', 'Education', 'Health & Fitness',
#        'Lifestyle', 'Medical', 'Weather', 'Book', 'Catalogs'],
#       dtype=object)

# %%
apps_merge.loc[apps_merge['a_category'] == 'Travel']
# Out:
#                    name  a_size_mb  a_price  a_user_rating a_content_rating  \
# 3          Google Earth       35.5      0.0            3.5                1
# 29         DB Navigator       80.9      0.0            3.5                1
# 30   Southwest Airlines       84.7      0.0            3.0                1
# 41                 Uber      270.7      0.0            3.0                1
# 46            Fly Delta      134.3      0.0            3.0                1
# 52               Airbnb      232.5      0.0            4.0                1
# 78      United Airlines      134.4      0.0            2.5                1
# 219  Google Street View       91.5      0.0            4.0                1
# 243                SNCF      116.5      0.0            1.5                1
#
#     a_category          g_size_mb g_price  g_user_rating g_content_rating  \
# 3       Travel  Varies with devic       0            4.3                1
# 29      Travel                 20       0            4.0                1
# 30      Travel                8.3       0            3.9                1
# 41      Travel  Varies with devic       0            4.2                1
# 46      Travel                 46       0            3.7                1
# 52      Travel  Varies with devic       0            4.4                1
# 78      Travel                 80       0            3.5                1
# 219     Travel  Varies with devic       0            4.2                1
# 243     Travel  Varies with devic       0            3.4                1
#
#               g_category
# 3       TRAVEL_AND_LOCAL
# 29   MAPS_AND_NAVIGATION
# 30      TRAVEL_AND_LOCAL
# 41   MAPS_AND_NAVIGATION
# 46      TRAVEL_AND_LOCAL
# 52      TRAVEL_AND_LOCAL
# 78      TRAVEL_AND_LOCAL
# 219     TRAVEL_AND_LOCAL
# 243     TRAVEL_AND_LOCAL

# %%
apps_merge.loc[apps_merge['g_category'] == 'TRAVEL_AND_LOCAL']
# Out:
#                    name  a_size_mb  a_price  a_user_rating a_content_rating  \
# 3          Google Earth       35.5      0.0            3.5                1
# 30   Southwest Airlines       84.7      0.0            3.0                1
# 46            Fly Delta      134.3      0.0            3.0                1
# 52               Airbnb      232.5      0.0            4.0                1
# 78      United Airlines      134.4      0.0            2.5                1
# 219  Google Street View       91.5      0.0            4.0                1
# 243                SNCF      116.5      0.0            1.5                1
#
#     a_category          g_size_mb g_price  g_user_rating g_content_rating  \
# 3       Travel  Varies with devic       0            4.3                1
# 30      Travel                8.3       0            3.9                1
# 46      Travel                 46       0            3.7                1
# 52      Travel  Varies with devic       0            4.4                1
# 78      Travel                 80       0            3.5                1
# 219     Travel  Varies with devic       0            4.2                1
# 243     Travel  Varies with devic       0            3.4                1
#
#            g_category
# 3    TRAVEL_AND_LOCAL
# 30   TRAVEL_AND_LOCAL
# 46   TRAVEL_AND_LOCAL
# 52   TRAVEL_AND_LOCAL
# 78   TRAVEL_AND_LOCAL
# 219  TRAVEL_AND_LOCAL
# 243  TRAVEL_AND_LOCAL

# %%
#apps_merge.loc[~(apps_merge['a_category'] == apps_merge['g_category'])]

# %% [markdown]
# # Create connection to database

# %%
connection_string = (
    f"root:{mysql_conn.password}@localhost/my_db")
engine = create_engine(f'mysql://{connection_string}')

# %%
df.to_sql(
    name='df', con=engine, 
    if_exists='append', index=True)
